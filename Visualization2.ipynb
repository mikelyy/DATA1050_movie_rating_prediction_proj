# %% [raw]
# !pip install dash;

# %%
import numpy as np
import pandas as pd
import plotly

from preprocessing import *

toy_dict = load_obj("pop_movies")

df1 = pd.DataFrame(toy_dict).T

# rename columns
df1.columns=['title','year','content_rating','length','genres','score','metascore',
            'vote_numbers','gross','director','actors','genre']

# drop columns
df1.drop(['genres','metascore','actors'], axis=1, inplace=True)

# Drop duplicated movies
df1.title.drop_duplicates(inplace=True)
# Drop movies with any NaN
df1.replace('', np.nan, inplace=True)
df1.dropna(axis=0,how='any', inplace=True)

# %%
# delete min in length col
df1['length'] = [df1['length'][i][:-3] for i in range(len(df1['length']))]
# delete '$' and 'M' in gross col
df1['gross'] = [df1['gross'][i][1:-1] for i in range(len(df1['gross']))]
# delete non-integer in year col
df1['year'] = df1['year'].map(lambda x : ''.join([i for i in x if i.isdigit()]))

df1 = df1.convert_dtypes()
df1 = df1.astype({'length': 'int64','gross': 'float','score': 'float','year':'int32'})
df1.dtypes
# Out:
# title              string
# year                int32
# content_rating     string
# length              int64
# score             float64
# vote_numbers       string
# gross             float64
# director           string
# genre              string
# dtype: object

# %%
df1.describe()
# Out:
#               year       length        score        gross
# count  9502.000000  9502.000000  9502.000000  9502.000000
# mean   1998.608503   107.635866     6.483109    30.544057
# std      17.340524    20.902720     0.992997    58.335459
# min    1914.000000     9.000000     1.400000     0.000000
# 25%    1990.000000    94.000000     5.900000     0.770000
# 50%    2003.000000   104.000000     6.600000     8.725000
# 75%    2012.000000   117.000000     7.200000    35.187500
# max    2020.000000   566.000000     9.300000   936.660000

# %%
df1.head()
# Out:
#                                                    title  year content_rating  \
# tt6723592                                          Tenet  2020          PG-13
# tt4633694              Spider-Man: Into the Spider-Verse  2018             PG
# tt4154796                              Avengers: Endgame  2019          PG-13
# tt1477834                                        Aquaman  2018          PG-13
# tt2527338  Star Wars: Episode IX - The Rise of Skywalker  2019          PG-13
#
#            length  score vote_numbers   gross  \
# tt6723592     150    7.7      158,304   53.80
# tt4633694     117    8.4      357,781  190.24
# tt4154796     181    8.4      783,537  858.37
# tt1477834     143    6.9      361,542  335.06
# tt2527338     141    6.6      359,823  515.20
#
#                                                 director   genre
# tt6723592                              Christopher Nolan  action
# tt4633694  Bob Persichetti, Peter Ramsey, Rodney Rothman  action
# tt4154796                       Anthony Russo, Joe Russo  action
# tt1477834                                      James Wan  action
# tt2527338                                    J.J. Abrams  action

# %%
df1['year'].unique()
# Out:
# array([2020, 2018, 2019, 2016, 2001, 1988, 2008, 2010, 2000, 2017, 1999,
#        1965, 2006, 1984, 2012, 1977, 2014, 2003, 2009, 2005, 2007, 1997,
#        2015, 1981, 1994, 1990, 2002, 1989, 1993, 1986, 2011, 2013, 1996,
#        2004, 1982, 1987, 1967, 1980, 1991, 1995, 1983, 1979, 1992, 1998,
#        1963, 1971, 1962, 1973, 1969, 1964, 1985, 1954, 1974, 1978, 1960,
#        1976, 1959, 1968, 1972, 1956, 1970, 1961, 1927, 1966, 1975, 1938,
# tt6723592                              Christopher Nolan  action
# tt4633694  Bob Persichetti, Peter Ramsey, Rodney Rothman  action
# tt4154796                       Anthony Russo, Joe Russo  action
# tt1477834                                      James Wan  action
# tt2527338                                    J.J. Abrams  action
# ...                                                  ...     ...
# tt4717402              Shôjirô Nishimi, Guillaume Renard  action
# tt0490181                                   Simon Hunter  action
# tt1620933                               Tigmanshu Dhulia  action
# tt6836936                                        Sujeeth  action
# tt0104511                                    John Landis  action
#
# [1664 rows x 9 columns]

# %%
df1['genre'].unique()
# Out:
# <StringArray>
# [     'action',   'adventure',   'animation',   'biography',      'comedy',
#        'crime', 'documentary',       'drama',      'family',     'fantasy',
#    'film-noir',     'history',      'horror',       'music',     'musical',
#      'mystery',     'romance',      'sci-fi',       'short',       'sport',
#     'thriller',         'war',     'western']
# Length: 23, dtype: string

# %%
# app.py
# -*- coding: utf-8 -*-

# !pip install dash

import dash
import dash_table
import dash_core_components as dcc
import dash_html_components as html
import plotly.express as px
import plotly.graph_objects as go
from dash.dependencies import Input, Output


#external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']
external_stylesheets = ['https://unpkg.com/wingcss']

app = dash.Dash(__name__, external_stylesheets=external_stylesheets)


# see https://plotly.com/python/px-arguments/ for more options
# Drop years before 2015
df2 = df1[~(df1['year'] < 2015)]

# App layout
app.layout = html.Div([

    html.H1("Movies", style={'text-align': 'center'}),
    html.Div([
    html.Div(children='''
        Graph showing relationship between score and vote numbers of different genres of movies.
    '''),

    dcc.Dropdown(id="slct_year",
                 options=[
                     {"label": "2015", "value": 2015},
                     {"label": "2016", "value": 2016},
                     {"label": "2017", "value": 2017},
                     {"label": "2018", "value": 2018},
                     {"label": "2019", "value": 2019},
                     {"label": "2020", "value": 2020}],
                 multi=False,
                 value=2015,
                 style={'width': "50%"}
                 ),
    html.Br(),
    html.Div(id='output_container', children=[]),
    html.Br(),

    dcc.Graph(id='movie_scatter', figure={})],style={'width': '75%', 'display': 'inline-block'}),
    html.Div( #smaller now moved up beside the first block
    [
        html.I("Search a movie to view its score trend:"),
        html.Br(),
        dcc.Input(id="input1", type="text", placeholder="Your movie title..."),
        html.Div(id="output"),
    ],style={'width': '20%', 'display': 'inline-block', 'margin':'auto'}),

    html.Div(html.H2("Movie info per genre", style={'text-align': 'center'})),

    html.Div([
        dcc.Markdown('''
        This table shows 9502 trending movies from all genre.
        
        Use the filter box in each column to filter data.
        
        Genres include:
        *action, adventure, animation, biography, comedy, crime, 
        documentary, drama, family, fantasy, film-noir, history, horror, music, musical, 
        mystery, romance, sci-fi, short, sport, thriller, war, western*
        '''),  
        dash_table.DataTable(
        id='datatable-interactivity',
        columns=[
            {"name": i, "id": i, "deletable": True, "selectable": True}
            for i in df1.columns
        ],

        data=df1.to_dict('records'),  # the contents of the table
        filter_action="native",     # allow filtering of data by user ('native') or not ('none')
        sort_action="native",       # enables data to be sorted per-column by user or not ('none')
        sort_mode="single",         # sort across 'multi' or 'single' columns
        row_deletable=True,         # choose if user can delete a row (True) or not (False)
        page_action="native",       # all data is passed to the table up-front or not ('none')
        page_current=0,             # page number that user is on
        page_size=8,                # number of rows visible per page
        style_cell={                # ensure adequate header width when text is shorter than cell's text
            'textAlign': 'left','minWidth': 95, 'maxWidth': 95, 'width': 95
        },
        style_data={                # overflow cells' content into multiple lines
            'whiteSpace': 'normal',
            'height': 'auto',
        'lineHeight': '15px'
        }
    ),html.Br()]),
    html.Hr(),
    html.Div([
        
        html.Br(),
        dcc.Tabs([
            dcc.Tab(label='Action', children=[
                dcc.Graph(
                    figure=px.scatter(df1[df1['genre'] == 'action'], x="length", y="score", marginal_y="violin",
           marginal_x="box", trendline="ols", template="simple_white")
                )
            ]),
            dcc.Tab(label='Adventure', children=[
                dcc.Graph(
                    figure=px.scatter(df1[df1['genre'] == 'adventure'], x="length", y="score", marginal_y="violin",
           marginal_x="box", trendline="ols", template="simple_white")
                )]),
            dcc.Tab(label='Animation', children=[
                dcc.Graph(
                    figure=px.scatter(df1[df1['genre'] == 'animation'], x="length", y="score", marginal_y="violin",
           marginal_x="box", trendline="ols", template="simple_white")
                )]),
            dcc.Tab(label='Biography', children=[
                dcc.Graph(
                    figure=px.scatter(df1[df1['genre'] == 'biography'], x="length", y="score", marginal_y="violin",
           marginal_x="box", trendline="ols", template="simple_white")
                )]),
            dcc.Tab(label='Comedy', children=[
                dcc.Graph(
                    figure=px.scatter(df1[df1['genre'] == 'comedy'], x="length", y="score", marginal_y="violin",
           marginal_x="box", trendline="ols", template="simple_white")
                )]),
            dcc.Tab(label='Crime', children=[
                dcc.Graph(
                    figure=px.scatter(df1[df1['genre'] == 'crime'], x="length", y="score", marginal_y="violin",
           marginal_x="box", trendline="ols", template="simple_white")
                )]),
            dcc.Tab(label='Drama', children=[
                dcc.Graph(
                    figure=px.scatter(df1[df1['genre'] == 'drama'], x="length", y="score", marginal_y="violin",
           marginal_x="box", trendline="ols", template="simple_white")
                )]),
            dcc.Tab(label='Family', children=[
                dcc.Graph(
                    figure=px.scatter(df1[df1['genre'] == 'family'], x="length", y="score", marginal_y="violin",
           marginal_x="box", trendline="ols", template="simple_white")
                )]),

            dcc.Tab(label='Fantasy', children=[
                dcc.Graph(
                    figure=px.scatter(df1[df1['genre'] == 'fantasy'], x="length", y="score", marginal_y="violin",
           marginal_x="box", trendline="ols", template="simple_white")
                )]),
            dcc.Tab(label='Horror', children=[
                dcc.Graph(
                    figure=px.scatter(df1[df1['genre'] == 'horror'], x="length", y="score", marginal_y="violin",
           marginal_x="box", trendline="ols", template="simple_white")
                )]),
            dcc.Tab(label='Music', children=[
                dcc.Graph(
                    figure=px.scatter(df1[df1['genre'] == 'music'], x="length", y="score", marginal_y="violin",
           marginal_x="box", trendline="ols", template="simple_white")
                )]),
            dcc.Tab(label='Romance', children=[
                dcc.Graph(
                    figure=px.scatter(df1[df1['genre'] == 'romance'], x="length", y="score", marginal_y="violin",
           marginal_x="box", trendline="ols", template="simple_white")
                )
            ])
        ])
    ])
])


# ------------------------------------------------------------------------------
# Connect the Plotly graphs with Dash Components
@app.callback(
    [Output(component_id='output_container', component_property='children'),
     Output(component_id='movie_scatter', component_property='figure')],
    [Input(component_id='slct_year', component_property='value')]
)
def update_graph(option_slctd):

    container = "Year of {}".format(option_slctd)

    dff = df2.copy()
    dff = dff[dff["year"] == option_slctd]

    # Plotly Express
    fig = px.scatter(dff, x="vote_numbers", y="score",
                 size="gross", color="genre", hover_name="title",
                 log_x=True, size_max=60)

    return container, fig

if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [03/Dec/2020 02:45:22] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Dec/2020 02:45:22] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Dec/2020 02:45:22] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Dec/2020 02:45:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Dec/2020 02:46:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Dec/2020 02:46:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Dec/2020 02:47:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Dec/2020 02:47:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Dec/2020 03:22:03] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Dec/2020 03:22:04] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Dec/2020 03:22:05] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Dec/2020 03:22:05] "POST /_dash-update-component HTTP/1.1" 200 -

# %%
df1.to_json(r'pop_movies.json')

# %% [markdown]
# ## Examples of graphs in above dash

# %%
# Overall plot
px.scatter(df2, x="vote_numbers", y="score",
                 size="gross", color="genre", hover_name="title",
                 log_x=True, size_max=60)
# Out:
# <div>                            <div id="e9bc630e-8575-4c58-bf04-851c90dc59ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e9bc630e-8575-4c58-bf04-851c90dc59ac")) {                    Plotly.newPlot(                        "e9bc630e-8575-4c58-bf04-851c90dc59ac",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>genre=action<br>vote_numbers=%{x}<br>score=%{y}<br>gross=%{marker.size}<extra></extra>", "hovertext": ["Tenet", "Spider-Man: Into the Spider-Verse", "Avengers: Endgame", "Aquaman", "Star Wars: Episode IX - The Rise of Skywalker", "Mortal Engines", "Deadpool", "Deadpool 2", "Avengers: Infinity War", "Birds of Prey: And the Fantabulous Emancipation of One Harley Quinn", "Ford v Ferrari", "Bad Boys for Life", "Blade Runner 2049", "Jumanji: The Next Level", "Black Panther", "Terminator: Dark Fate", "Ready Player One", "Wonder Woman", "Rogue One: A Star Wars Story", "Thor: Ragnarok", "Mission: Impossible - Fallout", "Solo: A Star Wars Story", "Mad Max: Fury Road", "Justice League", "Spider-Man: Far from Home", "Suicide Squad", "Mile 22", "Spectre", "Captain Marvel", "Gemini Man", "Spider-Man: Homecoming", "Logan", "Star Wars: Episode VII - The Force Awakens", "John Wick: Chapter 3 - Parabellum", "Pirates of the Caribbean: Dead Men Tell No Tales", "Alita: Battle Angel", "Red Sparrow", "Fast & Furious Presents: Hobbs & Shaw", "Guardians of the Galaxy Vol. 2", "Jumanji: Welcome to the Jungle", "Jurassic World: Fallen Kingdom", "Dunkirk", "Sonic the Hedgehog", "The Nice Guys", "Star Wars: Episode VIII - The Last Jedi", "The Revenant", "Doctor Strange", "Baby Driver", "Ocean's Eight", "Shazam!", "Venom", "Jurassic World", "The Predator", "Avengers: Age of Ultron", "Batman v Superman: Dawn of Justice", "The Man from U.N.C.L.E.", "Morgan", "X-Men: Dark Phoenix", "Baywatch", "X-Men: Apocalypse", "Zombieland: Double Tap", "Sicario", "Train to Busan", "Captain America: Civil War", "Anna", "John Wick: Chapter 2", "King Arthur: Legend of the Sword", "The Mummy", "The Magnificent Seven", "Ant-Man", "Free State of Jones", "Geostorm", "Overlord", "Godzilla: King of the Monsters", "Game Night", "Kingsman: The Golden Circle", "Angel Has Fallen", "The Meg", "Jason Bourne", "Ghost in the Shell", "Men in Black: International", "Maze Runner: The Death Cure", "Den of Thieves", "Incredibles 2", "The Girl in the Spider's Web", "Mission: Impossible - Rogue Nation", "Transformers: The Last Knight", "Jack Reacher: Never Go Back", "Star Trek Beyond", "Upgrade", "Escape Room", "10 Cloverfield Lane", "13 Hours", "Rambo: Last Blood", "Terminator Genisys", "Tomorrowland", "Assassin's Creed", "The Dark Tower", "Maze Runner: The Scorch Trials", "Fantastic Four", "Robin Hood", "Furious 7", "Mandy", "The Foreigner", "Gods of Egypt", "Hellboy", "Warcraft", "Valerian and the City of a Thousand Planets", "American Assassin", "Spy", "Sicario: Day of the Soldado", "Bumblebee", "Peppermint", "The Accountant", "Ant-Man and the Wasp", "Cold Pursuit", "Independence Day: Resurgence", "The Fate of the Furious", "The Hunger Games: Mockingjay - Part 2", "Atomic Blonde", "Now You See Me 2", "Pok\u00e9mon Detective Pikachu", "Criminal", "Kong: Skull Island", "The Hitman's Bodyguard", "Inferno", "Everest", "How to Train Your Dragon: The Hidden World", "Hunter Killer", "Power Rangers", "Hotel Mumbai", "Central Intelligence", "Jupiter Ascending", "The 5th Wave", "Southpaw", "The Take", "Tomb Raider", "The Legend of Tarzan", "Rampage", "Pacific Rim: Uprising", "Allied", "Hell or High Water", "Deepwater Horizon", "Adrift", "The Equalizer 2", "Crawl", "The Huntsman: Winter's War", "The Finest Hours", "In the Heart of the Sea", "San Andreas", "American Made", "The Great Wall", "Slaughterhouse Rulez", "Ip Man 4: The Finale" ...

# %%
# Plots By Genre
px.scatter(df1[df1['genre'] == 'adventure'], x="length", y="score", marginal_y="violin",
           marginal_x="box", trendline="ols", template="simple_white").show()
# Out:
# <div>                            <div id="cdd88080-45d0-48d6-ac40-355b212149c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cdd88080-45d0-48d6-ac40-355b212149c4")) {                    Plotly.newPlot(                        "cdd88080-45d0-48d6-ac40-355b212149c4",                        [{"hovertemplate": "length=%{x}<br>score=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#1F77B4", "symbol": "circle"}, "mode": "markers", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x":
 97, 114, 88, 95, 105, 96, 125, 146, 129, 77, 85, 85, 81, 97, 88, 94, 99, 91, 76, 85, 116, 92, 80, 111, 93, 103, 97, 86, 99, 100, 106, 108, 111, 92, 88, 101, 109, 100, 91, 114, 170, 105, 99, 112, 96, 95, 125, 100, 76, 117, 99, 100, 103, 143, 102, 74, 103, 79, 86, 75, 72, 90, 99, 87, 76, 74, 105, 115, 103, 88, 150, 114, 108, 111, 87, 89, 102, 108, 94, 126, 98, 112, 86, 103, 114, 97, 90, 112, 96, 108, 87, 80, 89, 127, 105, 87, 119, 89, 161, 122, 95, 138, 87, 108, 101, 105, 114, 78, 76, 104, 101, 75, 114, 98, 119, 96, 91, 105, 96, 106, 71, 109, 99, 108, 90, 83, 109, 98, 91, 125, 94, 85, 107, 94, 128, 118, 90, 93, 100, 90, 126, 95, 86, 92, 106, 118, 101, 126, 94, 72, 116, 104, 73,  ...

# %%
import pandas as pd
import numpy as np
from preprocessing import *

toy_dict = load_obj("dark knight")

reviews = list(toy_dict.values())[0][13]
scores = [int(x[0]) for x in reviews]
date = [x[2] for x in reviews]

d = {'date':date,'score':scores}
df = pd.DataFrame(d)
df['date'] = pd.to_datetime(df['date'])
df = df.astype({'score': 'float'})
df.dtypes
# Out:
# date     datetime64[ns]
# score           float64
# dtype: object

# %%
df = df.sort_values(by=['date'])
df.head()
# Out:
#          date  score
# 82 2008-07-06    7.0
# 9  2008-07-07   10.0
# 16 2008-07-07   10.0
# 2  2008-07-09   10.0
# 99 2008-07-13    9.0

# %%
df['cum-avg'] = df['score'].expanding().mean().to_list()
df.head()
# Out:
#          date  score  cum-avg
# 82 2008-07-06    7.0     7.00
# 9  2008-07-07   10.0     8.50
# 16 2008-07-07   10.0     9.00
# 2  2008-07-09   10.0     9.25
# 99 2008-07-13    9.0     9.20

# %%
import plotly.express as px 

df['cum-avg'] = df['score'].expanding().mean().to_list()
# Plot 
trend_fig = px.line(df, x='date', y=['cum-avg'])
# add another
trend_fig.add_scatter(x=df['date'], y=df['score'],mode='markers', name='Individual Score')
trend_fig.update_layout( height=800, title_text='Score Trend Over Time')
# Show plot 
trend_fig.show()
# Out:
# <div>                            <div id="1ba39f8c-5fe4-4785-a8e4-01a00a25368f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ba39f8c-5fe4-4785-a8e4-01a00a25368f")) {                    Plotly.newPlot(                        "1ba39f8c-5fe4-4785-a8e4-01a00a25368f",                        [{"hovertemplate": "variable=cum-avg<br>date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "cum-avg", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "cum-avg", "showlegend": true, "type": "scattergl", "x": ["2008-07-06T00:00:00", "2008-07-07T00:00:00", "2008-07-07T00:00:00", "2008-07-09T00:00:00", "2008-07-13T00:00:00", "2008-07-14T00:00:00", "2008-07-14T00:00:00", "2008-07-14T00:00:00", "2008-07-14T00:00:00", "2008-07-14T00:00:00", "2008-07-15T00:00:00", "2008-07-15T00:00:00", "2008-07-15T00:00:00", "2008-07-15T00:00:00", "2008-07-15T00:00:00", "2008-07-15T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-16T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-17T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T00:00:00", "2008-07-18T0 ...
